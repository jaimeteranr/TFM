# %%
import src.notebooks.evaluacion_masiva as evaluacion
# Out:
# ...
# GENERANDO SEMANA 1/71
# ...
# Semana: 2024-08-05
# Trabajadores: 9
#
# ...
# VACANZE ROMANE
# ...
#
# Semana: 2024-08-05 00:00:00
#
# ...
# MODELO DE PREDICCIÓN
# ...
# Modelo: xgboost
# Tipo: completa
# Ruta: /Users/jaimeteran/Documents/PYTHON/VacanzeGIT/src/utils/predictor/models/completa
# ...
# /Users/jaimeteran/miniforge3/lib/python3.12/pickle.py:1760: UserWarning: [21:32:05] WARNING: /Users/runner/work/xgboost/xgboost/src/gbm/../common/error_msg.h:83: If you are loading a serialized model (like pickle in Python, RDS in R) or
# configuration generated by an older version of XGBoost, please export the model by calling
# `Booster.save_model` from that version first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/stable/tutorials/saving_model.html
#
# for more details about differences between saving model and serializing.
#
#   setstate(state)
# SOLVER: LIBRE
#     entrada_norm  duracion_norm
# 630        17:00            5.0
# 631        17:00            5.5
# ...
