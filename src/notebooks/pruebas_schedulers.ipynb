# %%
import pandas as pd
import numpy as np
import importlib

import src.scheduler.scheduler as scheduler

importlib.reload(scheduler)
# Out:
# ...
# VACANZE ROMANE
# ...
#
# Semana: 2026-06-15
#
# ...
# REGLAS
# ...
#
# minutos_montaje: 30
# minutos_recogida: 30
# min_personas_apertura: 1
# min_personas_cierre: 2
# max_horas_dias: 9
# max_dias_semana: 5
# min_horas_dia: 5
# horas_semanales: 40
# descanso_entre_turnos: 12
#
# DEBUG HORARIO_BASE
#
#   dia_semana  apertura    cierre
# 0      lunes  12:30:00  01:30:00
# 1     martes  12:30:00  01:30:00
# 2  miercoles  12:30:00  01:30:00
# 3     jueves  12:30:00  01:30:00
# 4    viernes  12:30:00  01:30:00
# 5     sabado  12:30:00  01:30:00
# 6    domingo  12:30:00  01:30:00
# 7      lunes  12:30:00  23:30:00
# 8     martes       NaN       NaN
# 9  miercoles  12:30:00  23:30:00
# <class 'datetime.time'>
# <class 'datetime.time'>
#
# ...
# TEMPORADA
# ...
#
# verano
#
# HORARIOS BASE COMPLETOS
#
# Monday {'abierto': 1, 'apertura': '12:30', 'cierre': '01:30'}
# Tuesday {'abierto': 1, 'apertura': '12:30', 'cierre': '01:30'}
# Wednesday {'abierto': 1, 'apertura': '12:30', 'cierre': '01:30'}
# ...
